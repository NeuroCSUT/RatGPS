# %%
from scipy.io import loadmat

X = loadmat("all_neurons_20ms.mat")
y = loadmat("locations_20ms.mat")

# %%
print X.keys(), y.keys()
# Out:
# ['mm', '__version__', '__header__', '__globals__'] ['loc', '__version__', '__header__', '__globals__']

# %%
print X['mm'].shape, y['loc'].shape
# Out:
# (172L, 54100L) (54100L, 2L)

# %%
X = X['mm'].T
y = y['loc'] / 3.5

# %%
import numpy as np

print np.min(X), np.max(X), np.mean(X)
# Out:
# 0 10 0.0351700124661

# %%
print np.min(y, axis=0), np.max(y, axis=0), np.mean(y, axis=0)
# Out:
# [ 6.03855572  4.34378814] [ 107.1999615   105.25543277] [ 60.78295986  57.36000795]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(16,6))

plt.subplot(1,2,1)
plt.plot(y[:,0], y[:,1]);

plt.subplot(1,2,2)
plt.plot(y[:500,0], y[:500,1]);

# %%
d = np.sqrt(np.sum(np.square(y[1:] - y[:-1]), axis=1))
print d.shape, np.min(d), np.max(d), np.mean(d)
plt.plot(d)
# Out:
# (54099L,) 0.0 1.63144984234 0.388314802108
